# %%
num = int(input())
if num % 3 == 0:
    print('fizz')
if num % 5 == 0:
    print('buzz')
else:
    print(num)
# Out:
#  30
# fizz
# buzz

# %%
num = int(input())
if num % 2 == 0:
    print(f"{num} is even")
if num % 2 == 1:
    print(f"{num} is even")
# Out:
#  12
# 12 is even

# %%
num = int(input())
if num % 3 == 0 and num % 5 == 0:
    print('fizzBuzz')
elif num % 3 == 0:
    print('fizz')
elif num % 5 == 0:
    print('Buzz')
else:
    print(num)
# Out:
#  15
# fizzBuzz

# %%
num = int(input())
if num > 0:
    print(f"{num} is postive")
elif num < 0 :
    print(f"{num} is negitive")
else:
    print('0')
# Out:
#  0
# 0

# %%
num = int(input())
if num>=0 and num%2==0:
    print(f"{num} is positive even")
elif num>0 and num%2!=0:
    print(f'{num} is positive odd')
elif num<0 and num%2==0:
    print(f'{num} is negitive even')
else:
    print(f'{num} is negitive odd')
# Out:
#  0
# 0 is positive even

# %%
num = int(input())
if num>0 and num%2==0:
    print(f"{num} is positive even")
elif num>0:
    print(f'{num} is positive odd')
elif num<0 and num%2==0:
    print(f'{num} is negitive even')
elif num<0:
    print(f'{num} is negitive odd')
else:
    print("zero")
# Out:
#  0
# zero

# %%
# Find the Smaller Number among the three numbers
n1 = int(input())
n2 = int(input())
n3 = int(input())
if n1>n2>n3:
    print(n3)
elif n3>n2>n1:
    print(n1)
else:
    print(n2)
# Out:
#  1
#  2
#  3
# 1

# %%
num = int(input())
if num > 0:
    if num % 2 == 0:
        print(f'{num} is +ve even')
    else:
        print(f'{num} is +ve odd')
else:
    if num % 2 == 0:
        print(f'{num} is -ve even')
    else:
        print(f'{num} is -ve odd')
# Out:
#  3
# 3 is +ve odd

# %%
n1 = int(input())
n2 = int(input())
n3 = int(input())
if n1>n2 :
    if n1>n3:
        print(n1)
    
else:
    if n2>n3:
        print(n1)
    else:
        print(n3)
# Out:
#  99
#  1098
#  8
# 99
