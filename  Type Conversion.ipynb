# %%
## reading integer from 
## integer to float, string,bool
n = int(input())
print(type(n), n)
# Out:
#  srinu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 ## reading integer from
#       2 ## integer to float, string,bool
# ----> 3 n = int(input())
#       4 print(type(n), n)
#
# ValueError: invalid literal for int() with base 10: 'srinu'

# %%
n = int(input())
print(type(n), n)
print(float(n))
print(str(n))
print(bool(n))
# Out:
#  10
# <class 'int'> 10
# 10.0
# 10
# True

# %%
n = float(input())
print(type(n), n)
print(int(n))
print(str(n))
print(bool(n))
# Out:
#  22.77
# <class 'float'> 22.77
# 22
# 22.77
# True

# %%
n = float(input())
print(type(n), n)
print(int(n))
print(str(n)[:4])
print(bool(n))
print(str(n)[0:4:2])
print(str(n)[:3])
# Out:
#  234.777
# <class 'float'> 234.777
# 234
# 234.
# True
# 24
# 234

# %%
### reading string if values are numbers
s = str(input())
print(type(s), s)
print(int(s))
print(float(s))
print(bool(s))
# Out:
#  7
# <class 'str'> 7
# 7
# 7.0
# True

# %%
## reasding if string are characters
s = str(input())
print(type(s), s)
print(list(s))
print(tuple(s))
print(set(s))
print(list(s)[2:5:3])
# Out:
#  Mahesh
# <class 'str'> Mahesh
# ['M', 'a', 'h', 'e', 's', 'h']
# ('M', 'a', 'h', 'e', 's', 'h')
# {'e', 's', 'M', 'h', 'a'}
# ['h']

# %%
### reading complex value
real = int(input())
img = int(input())
c = complex(real, img)
print(type(c), c)
# Out:
#  10
#  5
# <class 'complex'> (10+5j)

# %%
## reading string value from user
s = input()
print(type(s), s)
print(int(s))
print(float(s))
print(list(s))  ## It returns list of characters
print(tuple(s)) ## It returns tuples of characters
print(set(s))  ## It returns set of characters
# Out:
#  1234
# <class 'str'> 1234
# 1234
# 1234.0
# ['1', '2', '3', '4']
# ('1', '2', '3', '4')
# {'4', '1', '2', '3'}

# %%
## reading string value from user
s = input()
print(type(s), s)
 # print(int(s))
l = list(s)
print(list[-4:5])  ## It returns list of characters
print(tuple(s)) ## It returns tuples of characters
print(set(s))  ## It returns set of characters

# %%
# reading List of integers
s = input().split()
print(s)
# Out:
#  1 2 3
# ['1', '2', '3']

# %%
s = map(int, input().split())
print(s)
# Out:
#  1 2 3
# <map object at 0x000001B27E75B010>

# %%
l= list(map(int, input().split()))
print(l)
print(tuple(l))
print(set(l))
s = str(l)
print(s[0])
print(s)
# Out:
#  1 2 3
# [1, 2, 3]
# (1, 2, 3)
# {1, 2, 3}
# [
# [1, 2, 3]

# %%
# read list of string

l = list(map(str, input().split()))
print(l)
# Out:
#  hello hi welcome y m
# ['hello', 'hi', 'welcome', 'y', 'm']

# %%
## Reading tuple of Integers
t = tuple(map(int, input().split()))
print(list(t))
print(set(t))
print(str(t))
# Out:
#  1 2 3 545 874 -58 -665
# [1, 2, 3, 545, 874, -58, -665]
# {1, 2, 3, 545, -58, -665, 874}
# (1, 2, 3, 545, 874, -58, -665)

# %%
## Reading tuple of Integers
s = set(map(int, input().split()))
print(list(s))
print(tuple(s))
print(str(s))
# Out:
#  1 23 4 5 6 7
# [1, 4, 5, 6, 7, 23]
# (1, 4, 5, 6, 7, 23)
# {1, 4, 5, 6, 7, 23}

# %%
## eval()(string) : it evalutes the string type expression
print("3+5")
print(3+5)
print(eval("3+5"))
# Out:
# 3+5
# 8
# 8

# %%
n = eval(input())
print(type(n), n)
# Out:
#  10.9
# <class 'float'> 10.9
