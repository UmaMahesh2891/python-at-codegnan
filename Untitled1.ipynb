# %%
What does print(-9 // 2) return?
Options:
A.
-4
B.
-5
C.
-4.5
D.
5

# %%
What is the output of the following Python expression? print(3 == 3.0)
Options:
A.
False
B.
True
C.
Error
D.
None

# %%
print(3 == 3.0)
# Out:
# True

# %%
What does 'b' in {'a': 1, 'b': 2} return in Python?
Options:
A.
TRUE
B.
FALSE
C.
2
D.
Error

# %%
'b' in {'a': 1, 'b': 2} return
# Out:
#   Cell In[2], line 1
#     'b' in {'a': 1, 'b': 2} return
#                             ^
# SyntaxError: invalid syntax

# %%
 What is the output of the following Python code snippet? a = 10 b = 20 c = a print(a is not b) print(a is c)
Options:
A.
False False
B.
False True
C.
True False
D.
True True

# %%
result = (10 != 5) == (8 > 12)
print(result)
# Out:
# False

# %%
Q29: What is the resulting output of the following Python script? str1 = "hello world" str2 = "hello world" list1 = [1, 2] list2 = [1, 2] print(str1 is str2) print(list1 is not list2)
Options:
A.
False False
B.
True False
C.
False True
D.
True True

# %%
Consider the following: a = 5 b = 5 print(a == b, a is b) What will be printed?
Options:
A.
True False
B.
False True
C.
True True
D.
False False
