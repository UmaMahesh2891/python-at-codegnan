# %%
result = []
l = [1,2,3,4,3,5,3,7,2]
target = 3
for i in l:
    if i == 3:
    pass
    else:
# Out:
#   Cell In[1], line 4
#     for i in l:
#                ^
# _IncompleteInputError: incomplete input
